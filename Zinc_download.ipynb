# %% [markdown]
# <a href="https://colab.research.google.com/github/quantaosun/Zinc-Million/blob/main/Zinc_download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prepare for downloading
#
# - The download script is generated on 10 Feb 2023

# %%
# !git clone https://github.com/quantaosun/Zinc-Million.git
# !cp /content/Zinc-Million/ZINC-downloader-3D-sdf.gz.wget .
# !cat ZINC-downloader-3D-sdf.gz.wget > download.sh
# Out:
# Cloning into 'Zinc-Million'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 31 (delta 11), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (31/31), 45.93 KiB | 452.00 KiB/s, done.

# %% [markdown]
# # Download

# %%
# !sh download.sh
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23449 (23K) [application/x-gzip]
# Saving to: ‘CF/BAMM/CFBAMM.xaa.sdf.gz’
#
# CF/BAMM/CFBAMM.xaa. 100%[===================>]  22.90K  --.-KB/s    in 0.08s
#
# 2023-02-11 23:09:15 (304 KB/s) - ‘CF/BAMM/CFBAMM.xaa.sdf.gz’ saved [23449/23449]
#
# mkdir: created directory 'CF/BAMO'
# --2023-02-11 23:09:15--  http://files.docking.org/3D/CF/BAMO/CFBAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 98722 (96K) [application/x-gzip]
# Saving to: ‘CF/BAMO/CFBAMO.xaa.sdf.gz’
#
# CF/BAMO/CFBAMO.xaa. 100%[===================>]  96.41K   373KB/s    in 0.3s
#
# 2023-02-11 23:09:16 (373 KB/s) - ‘CF/BAMO/CFBAMO.xaa.sdf.gz’ saved [98722/98722]
#
# mkdir: created directory 'CF/BAMP'
# --2023-02-11 23:09:16--  http://files.docking.org/3D/CF/BAMP/CFBAMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3154 (3.1K) [application/x-gzip]
# Saving to: ‘CF/BAMP/CFBAMP.xaa.sdf.gz’
#
# CF/BAMP/CFBAMP.xaa. 100%[===================>]   3.08K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:16 (329 MB/s) - ‘CF/BAMP/CFBAMP.xaa.sdf.gz’ saved [3154/3154]
#
# mkdir: created directory 'CF/BARL'
# --2023-02-11 23:09:16--  http://files.docking.org/3D/CF/BARL/CFBARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4998 (4.9K) [application/x-gzip]
# Saving to: ‘CF/BARL/CFBARL.xaa.sdf.gz’
#
# CF/BARL/CFBARL.xaa. 100%[===================>]   4.88K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:16 (272 MB/s) - ‘CF/BARL/CFBARL.xaa.sdf.gz’ saved [4998/4998]
#
# mkdir: created directory 'CF/BARM'
# --2023-02-11 23:09:16--  http://files.docking.org/3D/CF/BARM/CFBARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 156899 (153K) [application/x-gzip]
# Saving to: ‘CF/BARM/CFBARM.xaa.sdf.gz’
#
# CF/BARM/CFBARM.xaa. 100%[===================>] 153.22K   537KB/s    in 0.3s
#
# 2023-02-11 23:09:17 (537 KB/s) - ‘CF/BARM/CFBARM.xaa.sdf.gz’ saved [156899/156899]
#
# mkdir: created directory 'CF/BARO'
# --2023-02-11 23:09:17--  http://files.docking.org/3D/CF/BARO/CFBARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 268857 (263K) [application/x-gzip]
# Saving to: ‘CF/BARO/CFBARO.xaa.sdf.gz’
#
# CF/BARO/CFBARO.xaa. 100%[===================>] 262.56K   665KB/s    in 0.4s
#
# 2023-02-11 23:09:17 (665 KB/s) - ‘CF/BARO/CFBARO.xaa.sdf.gz’ saved [268857/268857]
#
# mkdir: created directory 'CF/BARP'
# --2023-02-11 23:09:17--  http://files.docking.org/3D/CF/BARP/CFBARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8919 (8.7K) [application/x-gzip]
# Saving to: ‘CF/BARP/CFBARP.xaa.sdf.gz’
#
# CF/BARP/CFBARP.xaa. 100%[===================>]   8.71K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:17 (120 MB/s) - ‘CF/BARP/CFBARP.xaa.sdf.gz’ saved [8919/8919]
#
# mkdir: created directory 'CF/BBML'
# --2023-02-11 23:09:17--  http://files.docking.org/3D/CF/BBML/CFBBML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 617 [application/x-gzip]
# Saving to: ‘CF/BBML/CFBBML.xaa.sdf.gz’
#
# CF/BBML/CFBBML.xaa. 100%[===================>]     617  --.-KB/s    in 0s
#
# 2023-02-11 23:09:17 (60.6 MB/s) - ‘CF/BBML/CFBBML.xaa.sdf.gz’ saved [617/617]
#
# mkdir: created directory 'CF/BBMM'
# --2023-02-11 23:09:17--  http://files.docking.org/3D/CF/BBMM/CFBBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9167 (9.0K) [application/x-gzip]
# Saving to: ‘CF/BBMM/CFBBMM.xaa.sdf.gz’
#
# CF/BBMM/CFBBMM.xaa. 100%[===================>]   8.95K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:18 (159 MB/s) - ‘CF/BBMM/CFBBMM.xaa.sdf.gz’ saved [9167/9167]
#
# mkdir: created directory 'CF/BBMO'
# --2023-02-11 23:09:18--  http://files.docking.org/3D/CF/BBMO/CFBBMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9570 (9.3K) [application/x-gzip]
# Saving to: ‘CF/BBMO/CFBBMO.xaa.sdf.gz’
#
# CF/BBMO/CFBBMO.xaa. 100%[===================>]   9.35K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:18 (144 MB/s) - ‘CF/BBMO/CFBBMO.xaa.sdf.gz’ saved [9570/9570]
#
# mkdir: created directory 'CF/BBMP'
# --2023-02-11 23:09:18--  http://files.docking.org/3D/CF/BBMP/CFBBMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1670 (1.6K) [application/x-gzip]
# Saving to: ‘CF/BBMP/CFBBMP.xaa.sdf.gz’
#
# CF/BBMP/CFBBMP.xaa. 100%[===================>]   1.63K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:18 (178 MB/s) - ‘CF/BBMP/CFBBMP.xaa.sdf.gz’ saved [1670/1670]
#
# mkdir: created directory 'CF/BBRL'
# --2023-02-11 23:09:18--  http://files.docking.org/3D/CF/BBRL/CFBBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4425 (4.3K) [application/x-gzip]
# Saving to: ‘CF/BBRL/CFBBRL.xaa.sdf.gz’
#
# CF/BBRL/CFBBRL.xaa. 100%[===================>]   4.32K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:18 (466 MB/s) - ‘CF/BBRL/CFBBRL.xaa.sdf.gz’ saved [4425/4425]
#
# mkdir: created directory 'CF/BBRM'
# --2023-02-11 23:09:18--  http://files.docking.org/3D/CF/BBRM/CFBBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76913 (75K) [application/x-gzip]
# Saving to: ‘CF/BBRM/CFBBRM.xaa.sdf.gz’
#
# CF/BBRM/CFBBRM.xaa. 100%[===================>]  75.11K   434KB/s    in 0.2s
#
# 2023-02-11 23:09:18 (434 KB/s) - ‘CF/BBRM/CFBBRM.xaa.sdf.gz’ saved [76913/76913]
#
# mkdir: created directory 'CF/BBRO'
# --2023-02-11 23:09:18--  http://files.docking.org/3D/CF/BBRO/CFBBRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90298 (88K) [application/x-gzip]
# Saving to: ‘CF/BBRO/CFBBRO.xaa.sdf.gz’
#
# CF/BBRO/CFBBRO.xaa. 100%[===================>]  88.18K   491KB/s    in 0.2s
#
# 2023-02-11 23:09:19 (491 KB/s) - ‘CF/BBRO/CFBBRO.xaa.sdf.gz’ saved [90298/90298]
#
# mkdir: created directory 'CF/BBRP'
# --2023-02-11 23:09:19--  http://files.docking.org/3D/CF/BBRP/CFBBRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11797 (12K) [application/x-gzip]
# Saving to: ‘CF/BBRP/CFBBRP.xaa.sdf.gz’
#
# CF/BBRP/CFBBRP.xaa. 100%[===================>]  11.52K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:19 (98.1 MB/s) - ‘CF/BBRP/CFBBRP.xaa.sdf.gz’ saved [11797/11797]
#
# mkdir: created directory 'CF/CAML'
# --2023-02-11 23:09:19--  http://files.docking.org/3D/CF/CAML/CFCAML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2781 (2.7K) [application/x-gzip]
# Saving to: ‘CF/CAML/CFCAML.xaa.sdf.gz’
#
# CF/CAML/CFCAML.xaa. 100%[===================>]   2.72K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:19 (130 MB/s) - ‘CF/CAML/CFCAML.xaa.sdf.gz’ saved [2781/2781]
#
# mkdir: created directory 'CF/CAMM'
# --2023-02-11 23:09:19--  http://files.docking.org/3D/CF/CAMM/CFCAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47117 (46K) [application/x-gzip]
# Saving to: ‘CF/CAMM/CFCAMM.xaa.sdf.gz’
#
# CF/CAMM/CFCAMM.xaa. 100%[===================>]  46.01K   291KB/s    in 0.2s
#
# 2023-02-11 23:09:20 (291 KB/s) - ‘CF/CAMM/CFCAMM.xaa.sdf.gz’ saved [47117/47117]
#
# mkdir: created directory 'CF/CAMO'
# --2023-02-11 23:09:20--  http://files.docking.org/3D/CF/CAMO/CFCAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72258 (71K) [application/x-gzip]
# Saving to: ‘CF/CAMO/CFCAMO.xaa.sdf.gz’
#
# CF/CAMO/CFCAMO.xaa. 100%[===================>]  70.56K   411KB/s    in 0.2s
#
# 2023-02-11 23:09:20 (411 KB/s) - ‘CF/CAMO/CFCAMO.xaa.sdf.gz’ saved [72258/72258]
#
# mkdir: created directory 'CF/CAMP'
# --2023-02-11 23:09:20--  http://files.docking.org/3D/CF/CAMP/CFCAMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4789 (4.7K) [application/x-gzip]
# Saving to: ‘CF/CAMP/CFCAMP.xaa.sdf.gz’
#
# CF/CAMP/CFCAMP.xaa. 100%[===================>]   4.68K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:20 (308 MB/s) - ‘CF/CAMP/CFCAMP.xaa.sdf.gz’ saved [4789/4789]
#
# mkdir: created directory 'CF/CARL'
# --2023-02-11 23:09:20--  http://files.docking.org/3D/CF/CARL/CFCARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2944 (2.9K) [application/x-gzip]
# Saving to: ‘CF/CARL/CFCARL.xaa.sdf.gz’
#
# CF/CARL/CFCARL.xaa. 100%[===================>]   2.88K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:20 (186 MB/s) - ‘CF/CARL/CFCARL.xaa.sdf.gz’ saved [2944/2944]
#
# mkdir: created directory 'CF/CARM'
# --2023-02-11 23:09:20--  http://files.docking.org/3D/CF/CARM/CFCARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84286 (82K) [application/x-gzip]
# Saving to: ‘CF/CARM/CFCARM.xaa.sdf.gz’
#
# CF/CARM/CFCARM.xaa. 100%[===================>]  82.31K   459KB/s    in 0.2s
#
# 2023-02-11 23:09:21 (459 KB/s) - ‘CF/CARM/CFCARM.xaa.sdf.gz’ saved [84286/84286]
#
# mkdir: created directory 'CF/CARO'
# --2023-02-11 23:09:21--  http://files.docking.org/3D/CF/CARO/CFCARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 157421 (154K) [application/x-gzip]
# Saving to: ‘CF/CARO/CFCARO.xaa.sdf.gz’
#
# CF/CARO/CFCARO.xaa. 100%[===================>] 153.73K   533KB/s    in 0.3s
#
# 2023-02-11 23:09:21 (533 KB/s) - ‘CF/CARO/CFCARO.xaa.sdf.gz’ saved [157421/157421]
#
# mkdir: created directory 'CF/CARP'
# --2023-02-11 23:09:21--  http://files.docking.org/3D/CF/CARP/CFCARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9316 (9.1K) [application/x-gzip]
# Saving to: ‘CF/CARP/CFCARP.xaa.sdf.gz’
#
# CF/CARP/CFCARP.xaa. 100%[===================>]   9.10K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:21 (126 MB/s) - ‘CF/CARP/CFCARP.xaa.sdf.gz’ saved [9316/9316]
#
# mkdir: created directory 'CF/CBML'
# --2023-02-11 23:09:21--  http://files.docking.org/3D/CF/CBML/CFCBML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1001 [application/x-gzip]
# Saving to: ‘CF/CBML/CFCBML.xaa.sdf.gz’
#
# CF/CBML/CFCBML.xaa. 100%[===================>]    1001  --.-KB/s    in 0s
#
# 2023-02-11 23:09:21 (110 MB/s) - ‘CF/CBML/CFCBML.xaa.sdf.gz’ saved [1001/1001]
#
# mkdir: created directory 'CF/CBMM'
# --2023-02-11 23:09:21--  http://files.docking.org/3D/CF/CBMM/CFCBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16415 (16K) [application/x-gzip]
# Saving to: ‘CF/CBMM/CFCBMM.xaa.sdf.gz’
#
# CF/CBMM/CFCBMM.xaa. 100%[===================>]  16.03K  --.-KB/s    in 0.07s
#
# 2023-02-11 23:09:22 (227 KB/s) - ‘CF/CBMM/CFCBMM.xaa.sdf.gz’ saved [16415/16415]
#
# mkdir: created directory 'EE/AARL'
# --2023-02-11 23:09:22--  http://files.docking.org/3D/EE/AARL/EEAARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 103341 (101K) [application/x-gzip]
# Saving to: ‘EE/AARL/EEAARL.xaa.sdf.gz’
#
# EE/AARL/EEAARL.xaa. 100%[===================>] 100.92K   449KB/s    in 0.2s
#
# 2023-02-11 23:09:22 (449 KB/s) - ‘EE/AARL/EEAARL.xaa.sdf.gz’ saved [103341/103341]
#
# mkdir: created directory 'EE/AARM'
# --2023-02-11 23:09:22--  http://files.docking.org/3D/EE/AARM/EEAARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3025077 (2.9M) [application/x-gzip]
# Saving to: ‘EE/AARM/EEAARM.xaa.sdf.gz’
#
# EE/AARM/EEAARM.xaa. 100%[===================>]   2.88M  2.71MB/s    in 1.1s
#
# 2023-02-11 23:09:23 (2.71 MB/s) - ‘EE/AARM/EEAARM.xaa.sdf.gz’ saved [3025077/3025077]
#
# mkdir: created directory 'EE/AARO'
# --2023-02-11 23:09:23--  http://files.docking.org/3D/EE/AARO/EEAARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10483275 (10.0M) [application/x-gzip]
# Saving to: ‘EE/AARO/EEAARO.xaa.sdf.gz’
#
# EE/AARO/EEAARO.xaa. 100%[===================>]  10.00M  3.91MB/s    in 2.6s
#
# 2023-02-11 23:09:26 (3.91 MB/s) - ‘EE/AARO/EEAARO.xaa.sdf.gz’ saved [10483275/10483275]
#
# mkdir: created directory 'EE/AARP'
# --2023-02-11 23:09:26--  http://files.docking.org/3D/EE/AARP/EEAARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 574868 (561K) [application/x-gzip]
# Saving to: ‘EE/AARP/EEAARP.xaa.sdf.gz’
#
# EE/AARP/EEAARP.xaa. 100%[===================>] 561.39K  1.21MB/s    in 0.5s
#
# 2023-02-11 23:09:27 (1.21 MB/s) - ‘EE/AARP/EEAARP.xaa.sdf.gz’ saved [574868/574868]
#
# mkdir: created directory 'EE/ABML'
# --2023-02-11 23:09:27--  http://files.docking.org/3D/EE/ABML/EEABML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23635 (23K) [application/x-gzip]
# Saving to: ‘EE/ABML/EEABML.xaa.sdf.gz’
#
# EE/ABML/EEABML.xaa. 100%[===================>]  23.08K  --.-KB/s    in 0.07s
#
# 2023-02-11 23:09:27 (311 KB/s) - ‘EE/ABML/EEABML.xaa.sdf.gz’ saved [23635/23635]
#
# mkdir: created directory 'EE/ABMM'
# --2023-02-11 23:09:27--  http://files.docking.org/3D/EE/ABMM/EEABMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 336454 (329K) [application/x-gzip]
# Saving to: ‘EE/ABMM/EEABMM.xaa.sdf.gz’
#
# EE/ABMM/EEABMM.xaa. 100%[===================>] 328.57K   993KB/s    in 0.3s
#
# 2023-02-11 23:09:27 (993 KB/s) - ‘EE/ABMM/EEABMM.xaa.sdf.gz’ saved [336454/336454]
#
# mkdir: created directory 'EE/ABMO'
# --2023-02-11 23:09:27--  http://files.docking.org/3D/EE/ABMO/EEABMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5894898 (5.6M) [application/x-gzip]
# Saving to: ‘EE/ABMO/EEABMO.xaa.sdf.gz’
#
# EE/ABMO/EEABMO.xaa. 100%[===================>]   5.62M  3.39MB/s    in 1.7s
#
# 2023-02-11 23:09:29 (3.39 MB/s) - ‘EE/ABMO/EEABMO.xaa.sdf.gz’ saved [5894898/5894898]
#
# mkdir: created directory 'EE/ABMP'
# --2023-02-11 23:09:29--  http://files.docking.org/3D/EE/ABMP/EEABMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 483248 (472K) [application/x-gzip]
# Saving to: ‘EE/ABMP/EEABMP.xaa.sdf.gz’
#
# EE/ABMP/EEABMP.xaa. 100%[===================>] 471.92K  1.01MB/s    in 0.5s
#
# 2023-02-11 23:09:30 (1.01 MB/s) - ‘EE/ABMP/EEABMP.xaa.sdf.gz’ saved [483248/483248]
#
# mkdir: created directory 'EE/ABRL'
# --2023-02-11 23:09:30--  http://files.docking.org/3D/EE/ABRL/EEABRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58177 (57K) [application/x-gzip]
# Saving to: ‘EE/ABRL/EEABRL.xaa.sdf.gz’
#
# EE/ABRL/EEABRL.xaa. 100%[===================>]  56.81K   355KB/s    in 0.2s
#
# 2023-02-11 23:09:30 (355 KB/s) - ‘EE/ABRL/EEABRL.xaa.sdf.gz’ saved [58177/58177]
#
# mkdir: created directory 'EE/ABRM'
# --2023-02-11 23:09:30--  http://files.docking.org/3D/EE/ABRM/EEABRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1647670 (1.6M) [application/x-gzip]
# Saving to: ‘EE/ABRM/EEABRM.xaa.sdf.gz’
#
# EE/ABRM/EEABRM.xaa. 100%[===================>]   1.57M  2.11MB/s    in 0.7s
#
# 2023-02-11 23:09:31 (2.11 MB/s) - ‘EE/ABRM/EEABRM.xaa.sdf.gz’ saved [1647670/1647670]
#
# mkdir: created directory 'EE/ABRO'
# --2023-02-11 23:09:31--  http://files.docking.org/3D/EE/ABRO/EEABRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6747322 (6.4M) [application/x-gzip]
# Saving to: ‘EE/ABRO/EEABRO.xaa.sdf.gz’
#
# EE/ABRO/EEABRO.xaa. 100%[===================>]   6.43M  3.47MB/s    in 1.9s
#
# 2023-02-11 23:09:33 (3.47 MB/s) - ‘EE/ABRO/EEABRO.xaa.sdf.gz’ saved [6747322/6747322]
#
# mkdir: created directory 'EE/ABRP'
# --2023-02-11 23:09:33--  http://files.docking.org/3D/EE/ABRP/EEABRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 246654 (241K) [application/x-gzip]
# Saving to: ‘EE/ABRP/EEABRP.xaa.sdf.gz’
#
# EE/ABRP/EEABRP.xaa. 100%[===================>] 240.87K   733KB/s    in 0.3s
#
# 2023-02-11 23:09:34 (733 KB/s) - ‘EE/ABRP/EEABRP.xaa.sdf.gz’ saved [246654/246654]
#
# mkdir: created directory 'EE/BAML'
# --2023-02-11 23:09:34--  http://files.docking.org/3D/EE/BAML/EEBAML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4633 (4.5K) [application/x-gzip]
# Saving to: ‘EE/BAML/EEBAML.xaa.sdf.gz’
#
# EE/BAML/EEBAML.xaa. 100%[===================>]   4.52K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:34 (296 MB/s) - ‘EE/BAML/EEBAML.xaa.sdf.gz’ saved [4633/4633]
#
# mkdir: created directory 'EE/BAMM'
# --2023-02-11 23:09:34--  http://files.docking.org/3D/EE/BAMM/EEBAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33319 (33K) [application/x-gzip]
# Saving to: ‘EE/BAMM/EEBAMM.xaa.sdf.gz’
#
# EE/BAMM/EEBAMM.xaa. 100%[===================>]  32.54K  --.-KB/s    in 0.08s
#
# 2023-02-11 23:09:34 (409 KB/s) - ‘EE/BAMM/EEBAMM.xaa.sdf.gz’ saved [33319/33319]
#
# mkdir: created directory 'EE/BAMO'
# --2023-02-11 23:09:34--  http://files.docking.org/3D/EE/BAMO/EEBAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 77054 (75K) [application/x-gzip]
# Saving to: ‘EE/BAMO/EEBAMO.xaa.sdf.gz’
#
# EE/BAMO/EEBAMO.xaa. 100%[===================>]  75.25K   431KB/s    in 0.2s
#
# 2023-02-11 23:09:35 (431 KB/s) - ‘EE/BAMO/EEBAMO.xaa.sdf.gz’ saved [77054/77054]
#
# mkdir: created directory 'EE/BAMP'
# --2023-02-11 23:09:35--  http://files.docking.org/3D/EE/BAMP/EEBAMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1828 (1.8K) [application/x-gzip]
# Saving to: ‘EE/BAMP/EEBAMP.xaa.sdf.gz’
#
# EE/BAMP/EEBAMP.xaa. 100%[===================>]   1.79K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:35 (131 MB/s) - ‘EE/BAMP/EEBAMP.xaa.sdf.gz’ saved [1828/1828]
#
# mkdir: created directory 'EE/BARL'
# --2023-02-11 23:09:35--  http://files.docking.org/3D/EE/BARL/EEBARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16049 (16K) [application/x-gzip]
# Saving to: ‘EE/BARL/EEBARL.xaa.sdf.gz’
#
# EE/BARL/EEBARL.xaa. 100%[===================>]  15.67K  --.-KB/s    in 0.07s
#
# 2023-02-11 23:09:35 (222 KB/s) - ‘EE/BARL/EEBARL.xaa.sdf.gz’ saved [16049/16049]
#
# mkdir: created directory 'EE/BARM'
# --2023-02-11 23:09:35--  http://files.docking.org/3D/EE/BARM/EEBARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 146343 (143K) [application/x-gzip]
# Saving to: ‘EE/BARM/EEBARM.xaa.sdf.gz’
#
# EE/BARM/EEBARM.xaa. 100%[===================>] 142.91K   515KB/s    in 0.3s
#
# 2023-02-11 23:09:35 (515 KB/s) - ‘EE/BARM/EEBARM.xaa.sdf.gz’ saved [146343/146343]
#
# mkdir: created directory 'EE/BARO'
# --2023-02-11 23:09:35--  http://files.docking.org/3D/EE/BARO/EEBARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104427 (102K) [application/x-gzip]
# Saving to: ‘EE/BARO/EEBARO.xaa.sdf.gz’
#
# EE/BARO/EEBARO.xaa. 100%[===================>] 101.98K   401KB/s    in 0.3s
#
# 2023-02-11 23:09:36 (401 KB/s) - ‘EE/BARO/EEBARO.xaa.sdf.gz’ saved [104427/104427]
#
# mkdir: created directory 'EE/BARP'
# --2023-02-11 23:09:36--  http://files.docking.org/3D/EE/BARP/EEBARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3505 (3.4K) [application/x-gzip]
# Saving to: ‘EE/BARP/EEBARP.xaa.sdf.gz’
#
# EE/BARP/EEBARP.xaa. 100%[===================>]   3.42K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:36 (318 MB/s) - ‘EE/BARP/EEBARP.xaa.sdf.gz’ saved [3505/3505]
#
# mkdir: created directory 'EE/BBML'
# --2023-02-11 23:09:36--  http://files.docking.org/3D/EE/BBML/EEBBML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3279 (3.2K) [application/x-gzip]
# Saving to: ‘EE/BBML/EEBBML.xaa.sdf.gz’
#
# EE/BBML/EEBBML.xaa. 100%[===================>]   3.20K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:36 (288 MB/s) - ‘EE/BBML/EEBBML.xaa.sdf.gz’ saved [3279/3279]
#
# mkdir: created directory 'EE/BBMM'
# --2023-02-11 23:09:36--  http://files.docking.org/3D/EE/BBMM/EEBBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16924 (17K) [application/x-gzip]
# Saving to: ‘EE/BBMM/EEBBMM.xaa.sdf.gz’
#
# EE/BBMM/EEBBMM.xaa. 100%[===================>]  16.53K  --.-KB/s    in 0.07s
#
# 2023-02-11 23:09:36 (232 KB/s) - ‘EE/BBMM/EEBBMM.xaa.sdf.gz’ saved [16924/16924]
#
# mkdir: created directory 'EE/BBMO'
# --2023-02-11 23:09:36--  http://files.docking.org/3D/EE/BBMO/EEBBMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 74082 (72K) [application/x-gzip]
# Saving to: ‘EE/BBMO/EEBBMO.xaa.sdf.gz’
#
# EE/BBMO/EEBBMO.xaa. 100%[===================>]  72.35K   420KB/s    in 0.2s
#
# 2023-02-11 23:09:37 (420 KB/s) - ‘EE/BBMO/EEBBMO.xaa.sdf.gz’ saved [74082/74082]
#
# mkdir: created directory 'EE/BBRL'
# --2023-02-11 23:09:37--  http://files.docking.org/3D/EE/BBRL/EEBBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9420 (9.2K) [application/x-gzip]
# Saving to: ‘EE/BBRL/EEBBRL.xaa.sdf.gz’
#
# EE/BBRL/EEBBRL.xaa. 100%[===================>]   9.20K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:37 (99.5 MB/s) - ‘EE/BBRL/EEBBRL.xaa.sdf.gz’ saved [9420/9420]
#
# mkdir: created directory 'EE/BBRM'
# --2023-02-11 23:09:37--  http://files.docking.org/3D/EE/BBRM/EEBBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 122709 (120K) [application/x-gzip]
# Saving to: ‘EE/BBRM/EEBBRM.xaa.sdf.gz’
#
# EE/BBRM/EEBBRM.xaa. 100%[===================>] 119.83K   443KB/s    in 0.3s
#
# 2023-02-11 23:09:37 (443 KB/s) - ‘EE/BBRM/EEBBRM.xaa.sdf.gz’ saved [122709/122709]
#
# mkdir: created directory 'EE/BBRO'
# --2023-02-11 23:09:37--  http://files.docking.org/3D/EE/BBRO/EEBBRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 99857 (98K) [application/x-gzip]
# Saving to: ‘EE/BBRO/EEBBRO.xaa.sdf.gz’
#
# EE/BBRO/EEBBRO.xaa. 100%[===================>]  97.52K   386KB/s    in 0.3s
#
# 2023-02-11 23:09:38 (386 KB/s) - ‘EE/BBRO/EEBBRO.xaa.sdf.gz’ saved [99857/99857]
#
# mkdir: created directory 'EE/BBRP'
# --2023-02-11 23:09:38--  http://files.docking.org/3D/EE/BBRP/EEBBRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3901 (3.8K) [application/x-gzip]
# Saving to: ‘EE/BBRP/EEBBRP.xaa.sdf.gz’
#
# EE/BBRP/EEBBRP.xaa. 100%[===================>]   3.81K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:38 (18.1 MB/s) - ‘EE/BBRP/EEBBRP.xaa.sdf.gz’ saved [3901/3901]
#
# mkdir: created directory 'EE/CAML'
# --2023-02-11 23:09:38--  http://files.docking.org/3D/EE/CAML/EECAML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5786 (5.7K) [application/x-gzip]
# Saving to: ‘EE/CAML/EECAML.xaa.sdf.gz’
#
# EE/CAML/EECAML.xaa. 100%[===================>]   5.65K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:38 (413 MB/s) - ‘EE/CAML/EECAML.xaa.sdf.gz’ saved [5786/5786]
#
# mkdir: created directory 'EE/CAMM'
# --2023-02-11 23:09:38--  http://files.docking.org/3D/EE/CAMM/EECAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 78640 (77K) [application/x-gzip]
# Saving to: ‘EE/CAMM/EECAMM.xaa.sdf.gz’
#
# EE/CAMM/EECAMM.xaa. 100%[===================>]  76.80K   437KB/s    in 0.2s
#
# 2023-02-11 23:09:38 (437 KB/s) - ‘EE/CAMM/EECAMM.xaa.sdf.gz’ saved [78640/78640]
#
# mkdir: created directory 'EE/CAMO'
# --2023-02-11 23:09:38--  http://files.docking.org/3D/EE/CAMO/EECAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59816 (58K) [application/x-gzip]
# Saving to: ‘EE/CAMO/EECAMO.xaa.sdf.gz’
#
# EE/CAMO/EECAMO.xaa. 100%[===================>]  58.41K   357KB/s    in 0.2s
#
# 2023-02-11 23:09:39 (357 KB/s) - ‘EE/CAMO/EECAMO.xaa.sdf.gz’ saved [59816/59816]
#
# mkdir: created directory 'EE/CAMP'
# --2023-02-11 23:09:39--  http://files.docking.org/3D/EE/CAMP/EECAMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5380 (5.3K) [application/x-gzip]
# Saving to: ‘EE/CAMP/EECAMP.xaa.sdf.gz’
#
# EE/CAMP/EECAMP.xaa. 100%[===================>]   5.25K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:39 (49.4 MB/s) - ‘EE/CAMP/EECAMP.xaa.sdf.gz’ saved [5380/5380]
#
# mkdir: created directory 'EE/CARL'
# --2023-02-11 23:09:39--  http://files.docking.org/3D/EE/CARL/EECARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15160 (15K) [application/x-gzip]
# Saving to: ‘EE/CARL/EECARL.xaa.sdf.gz’
#
# EE/CARL/EECARL.xaa. 100%[===================>]  14.80K  --.-KB/s    in 0.07s
#
# 2023-02-11 23:09:39 (214 KB/s) - ‘EE/CARL/EECARL.xaa.sdf.gz’ saved [15160/15160]
#
# mkdir: created directory 'EE/CARM'
# --2023-02-11 23:09:39--  http://files.docking.org/3D/EE/CARM/EECARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 235948 (230K) [application/x-gzip]
# Saving to: ‘EE/CARM/EECARM.xaa.sdf.gz’
#
# EE/CARM/EECARM.xaa. 100%[===================>] 230.42K   622KB/s    in 0.4s
#
# 2023-02-11 23:09:40 (622 KB/s) - ‘EE/CARM/EECARM.xaa.sdf.gz’ saved [235948/235948]
#
# mkdir: created directory 'EE/CARO'
# --2023-02-11 23:09:40--  http://files.docking.org/3D/EE/CARO/EECARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 98102 (96K) [application/x-gzip]
# Saving to: ‘EE/CARO/EECARO.xaa.sdf.gz’
#
# EE/CARO/EECARO.xaa. 100%[===================>]  95.80K   381KB/s    in 0.3s
#
# 2023-02-11 23:09:40 (381 KB/s) - ‘EE/CARO/EECARO.xaa.sdf.gz’ saved [98102/98102]
#
# mkdir: created directory 'EE/CARP'
# --2023-02-11 23:09:40--  http://files.docking.org/3D/EE/CARP/EECARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6233 (6.1K) [application/x-gzip]
# Saving to: ‘EE/CARP/EECARP.xaa.sdf.gz’
#
# EE/CARP/EECARP.xaa. 100%[===================>]   6.09K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:40 (373 MB/s) - ‘EE/CARP/EECARP.xaa.sdf.gz’ saved [6233/6233]
#
# mkdir: created directory 'EE/CBML'
# --2023-02-11 23:09:40--  http://files.docking.org/3D/EE/CBML/EECBML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4578 (4.5K) [application/x-gzip]
# Saving to: ‘EE/CBML/EECBML.xaa.sdf.gz’
#
# EE/CBML/EECBML.xaa. 100%[===================>]   4.47K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:40 (450 MB/s) - ‘EE/CBML/EECBML.xaa.sdf.gz’ saved [4578/4578]
#
# mkdir: created directory 'EE/CBMM'
# --2023-02-11 23:09:40--  http://files.docking.org/3D/EE/CBMM/EECBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39851 (39K) [application/x-gzip]
# Saving to: ‘EE/CBMM/EECBMM.xaa.sdf.gz’
#
# EE/CBMM/EECBMM.xaa. 100%[===================>]  38.92K  --.-KB/s    in 0.08s
#
# 2023-02-11 23:09:41 (462 KB/s) - ‘EE/CBMM/EECBMM.xaa.sdf.gz’ saved [39851/39851]
#
# mkdir: created directory 'EE/CBMO'
# --2023-02-11 23:09:41--  http://files.docking.org/3D/EE/CBMO/EECBMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38334 (37K) [application/x-gzip]
# Saving to: ‘EE/CBMO/EECBMO.xaa.sdf.gz’
#
# EE/CBMO/EECBMO.xaa. 100%[===================>]  37.44K  --.-KB/s    in 0.08s
#
# 2023-02-11 23:09:41 (453 KB/s) - ‘EE/CBMO/EECBMO.xaa.sdf.gz’ saved [38334/38334]
#
# mkdir: created directory 'EE/CBRL'
# --2023-02-11 23:09:41--  http://files.docking.org/3D/EE/CBRL/EECBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6570 (6.4K) [application/x-gzip]
# Saving to: ‘EE/CBRL/EECBRL.xaa.sdf.gz’
#
# EE/CBRL/EECBRL.xaa. 100%[===================>]   6.42K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:41 (586 MB/s) - ‘EE/CBRL/EECBRL.xaa.sdf.gz’ saved [6570/6570]
#
# mkdir: created directory 'EE/CBRM'
# --2023-02-11 23:09:41--  http://files.docking.org/3D/EE/CBRM/EECBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 105382 (103K) [application/x-gzip]
# Saving to: ‘EE/CBRM/EECBRM.xaa.sdf.gz’
#
# EE/CBRM/EECBRM.xaa. 100%[===================>] 102.91K   398KB/s    in 0.3s
#
# 2023-02-11 23:09:41 (398 KB/s) - ‘EE/CBRM/EECBRM.xaa.sdf.gz’ saved [105382/105382]
#
# mkdir: created directory 'EE/CBRO'
# --2023-02-11 23:09:41--  http://files.docking.org/3D/EE/CBRO/EECBRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48601 (47K) [application/x-gzip]
# Saving to: ‘EE/CBRO/EECBRO.xaa.sdf.gz’
#
# EE/CBRO/EECBRO.xaa. 100%[===================>]  47.46K   302KB/s    in 0.2s
#
# 2023-02-11 23:09:42 (302 KB/s) - ‘EE/CBRO/EECBRO.xaa.sdf.gz’ saved [48601/48601]
#
# mkdir: created directory 'EE/CBRP'
# --2023-02-11 23:09:42--  http://files.docking.org/3D/EE/CBRP/EECBRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3191 (3.1K) [application/x-gzip]
# Saving to: ‘EE/CBRP/EECBRP.xaa.sdf.gz’
#
# EE/CBRP/EECBRP.xaa. 100%[===================>]   3.12K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:42 (53.5 MB/s) - ‘EE/CBRP/EECBRP.xaa.sdf.gz’ saved [3191/3191]
#
# mkdir: created directory 'EE/EAML'
# --2023-02-11 23:09:42--  http://files.docking.org/3D/EE/EAML/EEEAML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2421 (2.4K) [application/x-gzip]
# Saving to: ‘EE/EAML/EEEAML.xaa.sdf.gz’
#
# EE/EAML/EEEAML.xaa. 100%[===================>]   2.36K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:42 (81.2 MB/s) - ‘EE/EAML/EEEAML.xaa.sdf.gz’ saved [2421/2421]
#
# mkdir: created directory 'EE/EAMM'
# --2023-02-11 23:09:42--  http://files.docking.org/3D/EE/EAMM/EEEAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 141044 (138K) [application/x-gzip]
# Saving to: ‘EE/EAMM/EEEAMM.xaa.sdf.gz’
#
# EE/EAMM/EEEAMM.xaa. 100%[===================>] 137.74K   487KB/s    in 0.3s
#
# 2023-02-11 23:09:42 (487 KB/s) - ‘EE/EAMM/EEEAMM.xaa.sdf.gz’ saved [141044/141044]
#
# mkdir: created directory 'EE/EAMO'
# --2023-02-11 23:09:42--  http://files.docking.org/3D/EE/EAMO/EEEAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 459193 (448K) [application/x-gzip]
# Saving to: ‘EE/EAMO/EEEAMO.xaa.sdf.gz’
#
# EE/EAMO/EEEAMO.xaa. 100%[===================>] 448.43K   348KB/s    in 1.3s
#
# 2023-02-11 23:09:44 (348 KB/s) - ‘EE/EAMO/EEEAMO.xaa.sdf.gz’ saved [459193/459193]
#
# mkdir: created directory 'EE/EAMP'
# --2023-02-11 23:09:44--  http://files.docking.org/3D/EE/EAMP/EEEAMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25987 (25K) [application/x-gzip]
# Saving to: ‘EE/EAMP/EEEAMP.xaa.sdf.gz’
#
# EE/EAMP/EEEAMP.xaa. 100%[===================>]  25.38K  --.-KB/s    in 0.08s
#
# 2023-02-11 23:09:44 (331 KB/s) - ‘EE/EAMP/EEEAMP.xaa.sdf.gz’ saved [25987/25987]
#
# mkdir: created directory 'EE/EARL'
# --2023-02-11 23:09:44--  http://files.docking.org/3D/EE/EARL/EEEARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11280 (11K) [application/x-gzip]
# Saving to: ‘EE/EARL/EEEARL.xaa.sdf.gz’
#
# EE/EARL/EEEARL.xaa. 100%[===================>]  11.02K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:44 (72.4 MB/s) - ‘EE/EARL/EEEARL.xaa.sdf.gz’ saved [11280/11280]
#
# mkdir: created directory 'EE/EARM'
# --2023-02-11 23:09:44--  http://files.docking.org/3D/EE/EARM/EEEARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 357175 (349K) [application/x-gzip]
# Saving to: ‘EE/EARM/EEEARM.xaa.sdf.gz’
#
# EE/EARM/EEEARM.xaa. 100%[===================>] 348.80K   924KB/s    in 0.4s
#
# 2023-02-11 23:09:45 (924 KB/s) - ‘EE/EARM/EEEARM.xaa.sdf.gz’ saved [357175/357175]
#
# mkdir: created directory 'EE/EARO'
# --2023-02-11 23:09:45--  http://files.docking.org/3D/EE/EARO/EEEARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 567674 (554K) [application/x-gzip]
# Saving to: ‘EE/EARO/EEEARO.xaa.sdf.gz’
#
# EE/EARO/EEEARO.xaa. 100%[===================>] 554.37K  1.22MB/s    in 0.4s
#
# 2023-02-11 23:09:45 (1.22 MB/s) - ‘EE/EARO/EEEARO.xaa.sdf.gz’ saved [567674/567674]
#
# mkdir: created directory 'EE/EARP'
# --2023-02-11 23:09:46--  http://files.docking.org/3D/EE/EARP/EEEARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19888 (19K) [application/x-gzip]
# Saving to: ‘EE/EARP/EEEARP.xaa.sdf.gz’
#
# EE/EARP/EEEARP.xaa. 100%[===================>]  19.42K  --.-KB/s    in 0.07s
#
# 2023-02-11 23:09:46 (268 KB/s) - ‘EE/EARP/EEEARP.xaa.sdf.gz’ saved [19888/19888]
#
# mkdir: created directory 'EE/EBML'
# --2023-02-11 23:09:46--  http://files.docking.org/3D/EE/EBML/EEEBML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3488 (3.4K) [application/x-gzip]
# Saving to: ‘EE/EBML/EEEBML.xaa.sdf.gz’
#
# EE/EBML/EEEBML.xaa. 100%[===================>]   3.41K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:46 (101 MB/s) - ‘EE/EBML/EEEBML.xaa.sdf.gz’ saved [3488/3488]
#
# mkdir: created directory 'EE/EBMM'
# --2023-02-11 23:09:46--  http://files.docking.org/3D/EE/EBMM/EEEBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57368 (56K) [application/x-gzip]
# Saving to: ‘EE/EBMM/EEEBMM.xaa.sdf.gz’
#
# EE/EBMM/EEEBMM.xaa. 100%[===================>]  56.02K   343KB/s    in 0.2s
#
# 2023-02-11 23:09:46 (343 KB/s) - ‘EE/EBMM/EEEBMM.xaa.sdf.gz’ saved [57368/57368]
#
# mkdir: created directory 'EE/EBMO'
# --2023-02-11 23:09:46--  http://files.docking.org/3D/EE/EBMO/EEEBMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 257775 (252K) [application/x-gzip]
# Saving to: ‘EE/EBMO/EEEBMO.xaa.sdf.gz’
#
# EE/EBMO/EEEBMO.xaa. 100%[===================>] 251.73K   646KB/s    in 0.4s
#
# 2023-02-11 23:09:47 (646 KB/s) - ‘EE/EBMO/EEEBMO.xaa.sdf.gz’ saved [257775/257775]
#
# mkdir: created directory 'EE/EBMP'
# --2023-02-11 23:09:47--  http://files.docking.org/3D/EE/EBMP/EEEBMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8757 (8.6K) [application/x-gzip]
# Saving to: ‘EE/EBMP/EEEBMP.xaa.sdf.gz’
#
# EE/EBMP/EEEBMP.xaa. 100%[===================>]   8.55K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:47 (19.0 MB/s) - ‘EE/EBMP/EEEBMP.xaa.sdf.gz’ saved [8757/8757]
#
# mkdir: created directory 'EE/EBRL'
# --2023-02-11 23:09:47--  http://files.docking.org/3D/EE/EBRL/EEEBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6927 (6.8K) [application/x-gzip]
# Saving to: ‘EE/EBRL/EEEBRL.xaa.sdf.gz’
#
# EE/EBRL/EEEBRL.xaa. 100%[===================>]   6.76K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:47 (182 MB/s) - ‘EE/EBRL/EEEBRL.xaa.sdf.gz’ saved [6927/6927]
#
# mkdir: created directory 'EE/EBRM'
# --2023-02-11 23:09:47--  http://files.docking.org/3D/EE/EBRM/EEEBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 255042 (249K) [application/x-gzip]
# Saving to: ‘EE/EBRM/EEEBRM.xaa.sdf.gz’
#
# EE/EBRM/EEEBRM.xaa. 100%[===================>] 249.06K   762KB/s    in 0.3s
#
# 2023-02-11 23:09:48 (762 KB/s) - ‘EE/EBRM/EEEBRM.xaa.sdf.gz’ saved [255042/255042]
#
# mkdir: created directory 'EE/EBRO'
# --2023-02-11 23:09:48--  http://files.docking.org/3D/EE/EBRO/EEEBRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 362796 (354K) [application/x-gzip]
# Saving to: ‘EE/EBRO/EEEBRO.xaa.sdf.gz’
#
# EE/EBRO/EEEBRO.xaa. 100%[===================>] 354.29K   825KB/s    in 0.4s
#
# 2023-02-11 23:09:48 (825 KB/s) - ‘EE/EBRO/EEEBRO.xaa.sdf.gz’ saved [362796/362796]
#
# mkdir: created directory 'EE/EBRP'
# --2023-02-11 23:09:48--  http://files.docking.org/3D/EE/EBRP/EEEBRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15819 (15K) [application/x-gzip]
# Saving to: ‘EE/EBRP/EEEBRP.xaa.sdf.gz’
#
# EE/EBRP/EEEBRP.xaa. 100%[===================>]  15.45K  --.-KB/s    in 0.07s
#
# 2023-02-11 23:09:48 (218 KB/s) - ‘EE/EBRP/EEEBRP.xaa.sdf.gz’ saved [15819/15819]
#
# mkdir: created directory 'CF/CBMO'
# --2023-02-11 23:09:48--  http://files.docking.org/3D/CF/CBMO/CFCBMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24325 (24K) [application/x-gzip]
# Saving to: ‘CF/CBMO/CFCBMO.xaa.sdf.gz’
#
# CF/CBMO/CFCBMO.xaa. 100%[===================>]  23.75K  --.-KB/s    in 0.08s
#
# 2023-02-11 23:09:49 (313 KB/s) - ‘CF/CBMO/CFCBMO.xaa.sdf.gz’ saved [24325/24325]
#
# mkdir: created directory 'CF/CBMP'
# --2023-02-11 23:09:49--  http://files.docking.org/3D/CF/CBMP/CFCBMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1693 (1.7K) [application/x-gzip]
# Saving to: ‘CF/CBMP/CFCBMP.xaa.sdf.gz’
#
# CF/CBMP/CFCBMP.xaa. 100%[===================>]   1.65K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:49 (74.4 MB/s) - ‘CF/CBMP/CFCBMP.xaa.sdf.gz’ saved [1693/1693]
#
# mkdir: created directory 'CF/CBRL'
# --2023-02-11 23:09:49--  http://files.docking.org/3D/CF/CBRL/CFCBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1140 (1.1K) [application/x-gzip]
# Saving to: ‘CF/CBRL/CFCBRL.xaa.sdf.gz’
#
# CF/CBRL/CFCBRL.xaa. 100%[===================>]   1.11K  --.-KB/s    in 0s
#
# 2023-02-11 23:09:49 (84.1 MB/s) - ‘CF/CBRL/CFCBRL.xaa.sdf.gz’ saved [1140/1140]
#
# mkdir: created directory 'CF/CBRM'
# --2023-02-11 23:09:49--  http://files.docking.org/3D/CF/CBRM/CFCBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32455 (32K) [application/x-gzip]
# Saving to: ‘CF/CBRM/CFCBRM.xaa.sdf.gz’
#
# CF/CBRM/CFCBRM.xaa. 100%[===================>]  31.69K  --.-KB/s    in 0.08s
#
# 2023-02-11 23:09:49 (398 KB/s) - ‘CF/CBRM/CFCBRM.xaa.sdf.gz’ saved [32455/32455]
#
# mkdir: created directory 'CF/CBRO'
# ...
#
# EG/CAMO/EGCAMO.xaa. 100%[===================>]  77.84K   446KB/s    in 0.2s
#
# 2023-02-11 23:12:36 (446 KB/s) - ‘EG/CAMO/EGCAMO.xaa.sdf.gz’ saved [79705/79705]
#
# mkdir: created directory 'EG/CAMP'
# --2023-02-11 23:12:36--  http://files.docking.org/3D/EG/CAMP/EGCAMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3289 (3.2K) [application/x-gzip]
# Saving to: ‘EG/CAMP/EGCAMP.xaa.sdf.gz’
#
# EG/CAMP/EGCAMP.xaa. 100%[===================>]   3.21K  --.-KB/s    in 0s
#
# 2023-02-11 23:12:36 (279 MB/s) - ‘EG/CAMP/EGCAMP.xaa.sdf.gz’ saved [3289/3289]
#
# mkdir: created directory 'EG/CARL'
# --2023-02-11 23:12:36--  http://files.docking.org/3D/EG/CARL/EGCARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9353 (9.1K) [application/x-gzip]
# Saving to: ‘EG/CARL/EGCARL.xaa.sdf.gz’
#
# EG/CARL/EGCARL.xaa. 100%[===================>]   9.13K  --.-KB/s    in 0s
#
# 2023-02-11 23:12:36 (93.4 MB/s) - ‘EG/CARL/EGCARL.xaa.sdf.gz’ saved [9353/9353]
#
# mkdir: created directory 'EG/CARM'
# --2023-02-11 23:12:36--  http://files.docking.org/3D/EG/CARM/EGCARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 244502 (239K) [application/x-gzip]
# Saving to: ‘EG/CARM/EGCARM.xaa.sdf.gz’
#
# EG/CARM/EGCARM.xaa. 100%[===================>] 238.77K   645KB/s    in 0.4s
#
# 2023-02-11 23:12:37 (645 KB/s) - ‘EG/CARM/EGCARM.xaa.sdf.gz’ saved [244502/244502]
#
# mkdir: created directory 'EG/CARO'
# --2023-02-11 23:12:37--  http://files.docking.org/3D/EG/CARO/EGCARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 168183 (164K) [application/x-gzip]
# Saving to: ‘EG/CARO/EGCARO.xaa.sdf.gz’
#
# EG/CARO/EGCARO.xaa. 100%[===================>] 164.24K   599KB/s    in 0.3s
#
# 2023-02-11 23:12:37 (599 KB/s) - ‘EG/CARO/EGCARO.xaa.sdf.gz’ saved [168183/168183]
#
# mkdir: created directory 'EG/CARP'
# --2023-02-11 23:12:37--  http://files.docking.org/3D/EG/CARP/EGCARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2794 (2.7K) [application/x-gzip]
# Saving to: ‘EG/CARP/EGCARP.xaa.sdf.gz’
#
# EG/CARP/EGCARP.xaa. 100%[===================>]   2.73K  --.-KB/s    in 0s
#
# 2023-02-11 23:12:38 (297 MB/s) - ‘EG/CARP/EGCARP.xaa.sdf.gz’ saved [2794/2794]
#
# mkdir: created directory 'EG/CBML'
# --2023-02-11 23:12:38--  http://files.docking.org/3D/EG/CBML/EGCBML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4201 (4.1K) [application/x-gzip]
# Saving to: ‘EG/CBML/EGCBML.xaa.sdf.gz’
#
# EG/CBML/EGCBML.xaa. 100%[===================>]   4.10K  --.-KB/s    in 0s
#
# 2023-02-11 23:12:38 (382 MB/s) - ‘EG/CBML/EGCBML.xaa.sdf.gz’ saved [4201/4201]
#
# mkdir: created directory 'EG/CBMM'
# --2023-02-11 23:12:38--  http://files.docking.org/3D/EG/CBMM/EGCBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40249 (39K) [application/x-gzip]
# Saving to: ‘EG/CBMM/EGCBMM.xaa.sdf.gz’
#
# EG/CBMM/EGCBMM.xaa. 100%[===================>]  39.31K  --.-KB/s    in 0.08s
#
# 2023-02-11 23:12:38 (468 KB/s) - ‘EG/CBMM/EGCBMM.xaa.sdf.gz’ saved [40249/40249]
#
# mkdir: created directory 'EG/CBMO'
# --2023-02-11 23:12:38--  http://files.docking.org/3D/EG/CBMO/EGCBMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42541 (42K) [application/x-gzip]
# Saving to: ‘EG/CBMO/EGCBMO.xaa.sdf.gz’
#
# EG/CBMO/EGCBMO.xaa. 100%[===================>]  41.54K  --.-KB/s    in 0.09s
#
# 2023-02-11 23:12:38 (487 KB/s) - ‘EG/CBMO/EGCBMO.xaa.sdf.gz’ saved [42541/42541]
#
# mkdir: created directory 'EG/CBMP'
# --2023-02-11 23:12:38--  http://files.docking.org/3D/EG/CBMP/EGCBMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4254 (4.2K) [application/x-gzip]
# Saving to: ‘EG/CBMP/EGCBMP.xaa.sdf.gz’
#
# EG/CBMP/EGCBMP.xaa. 100%[===================>]   4.15K  --.-KB/s    in 0s
#
# 2023-02-11 23:12:38 (367 MB/s) - ‘EG/CBMP/EGCBMP.xaa.sdf.gz’ saved [4254/4254]
#
# mkdir: created directory 'EG/CBRL'
# --2023-02-11 23:12:38--  http://files.docking.org/3D/EG/CBRL/EGCBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2162 (2.1K) [application/x-gzip]
# Saving to: ‘EG/CBRL/EGCBRL.xaa.sdf.gz’
#
# EG/CBRL/EGCBRL.xaa. 100%[===================>]   2.11K  --.-KB/s    in 0s
#
# 2023-02-11 23:12:39 (278 MB/s) - ‘EG/CBRL/EGCBRL.xaa.sdf.gz’ saved [2162/2162]
#
# mkdir: created directory 'EG/CBRM'
# --2023-02-11 23:12:39--  http://files.docking.org/3D/EG/CBRM/EGCBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 147083 (144K) [application/x-gzip]
# Saving to: ‘EG/CBRM/EGCBRM.xaa.sdf.gz’
#
# EG/CBRM/EGCBRM.xaa. 100%[===================>] 143.64K   513KB/s    in 0.3s
#
# 2023-02-11 23:12:39 (513 KB/s) - ‘EG/CBRM/EGCBRM.xaa.sdf.gz’ saved [147083/147083]
#
# mkdir: created directory 'EG/CBRO'
# --2023-02-11 23:12:39--  http://files.docking.org/3D/EG/CBRO/EGCBRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 77654 (76K) [application/x-gzip]
# Saving to: ‘EG/CBRO/EGCBRO.xaa.sdf.gz’
#
# EG/CBRO/EGCBRO.xaa. 100%[===================>]  75.83K   434KB/s    in 0.2s
#
# 2023-02-11 23:12:40 (434 KB/s) - ‘EG/CBRO/EGCBRO.xaa.sdf.gz’ saved [77654/77654]
#
# mkdir: created directory 'EG/CBRP'
# --2023-02-11 23:12:40--  http://files.docking.org/3D/EG/CBRP/EGCBRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6582 (6.4K) [application/x-gzip]
# Saving to: ‘EG/CBRP/EGCBRP.xaa.sdf.gz’
#
# EG/CBRP/EGCBRP.xaa. 100%[===================>]   6.43K  --.-KB/s    in 0s
#
# 2023-02-11 23:12:40 (262 MB/s) - ‘EG/CBRP/EGCBRP.xaa.sdf.gz’ saved [6582/6582]
#
# mkdir: created directory 'EG/EAML'
# --2023-02-11 23:12:40--  http://files.docking.org/3D/EG/EAML/EGEAML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-02-11 23:12:40 ERROR 404: Not Found.
#
# mkdir: created directory 'EG/EAMM'
# --2023-02-11 23:12:40--  http://files.docking.org/3D/EG/EAMM/EGEAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89884 (88K) [application/x-gzip]
# Saving to: ‘EG/EAMM/EGEAMM.xaa.sdf.gz’
#
# EG/EAMM/EGEAMM.xaa. 100%[===================>]  87.78K   483KB/s    in 0.2s
#
# 2023-02-11 23:12:40 (483 KB/s) - ‘EG/EAMM/EGEAMM.xaa.sdf.gz’ saved [89884/89884]
#
# mkdir: created directory 'EG/EAMO'
# --2023-02-11 23:12:40--  http://files.docking.org/3D/EG/EAMO/EGEAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 339953 (332K) [application/x-gzip]
# Saving to: ‘EG/EAMO/EGEAMO.xaa.sdf.gz’
#
# EG/EAMO/EGEAMO.xaa. 100%[===================>] 331.99K   845KB/s    in 0.4s
#
# 2023-02-11 23:12:41 (845 KB/s) - ‘EG/EAMO/EGEAMO.xaa.sdf.gz’ saved [339953/339953]
#
# mkdir: created directory 'EG/EAMP'
# --2023-02-11 23:12:41--  http://files.docking.org/3D/EG/EAMP/EGEAMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21723 (21K) [application/x-gzip]
# Saving to: ‘EG/EAMP/EGEAMP.xaa.sdf.gz’
#
# EG/EAMP/EGEAMP.xaa. 100%[===================>]  21.21K  --.-KB/s    in 0.07s
#
# 2023-02-11 23:12:41 (284 KB/s) - ‘EG/EAMP/EGEAMP.xaa.sdf.gz’ saved [21723/21723]
#
# mkdir: created directory 'EG/EARL'
# --2023-02-11 23:12:41--  http://files.docking.org/3D/EG/EARL/EGEARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8159 (8.0K) [application/x-gzip]
# Saving to: ‘EG/EARL/EGEARL.xaa.sdf.gz’
#
# EG/EARL/EGEARL.xaa. 100%[===================>]   7.97K  --.-KB/s    in 0s
#
# 2023-02-11 23:12:42 (234 MB/s) - ‘EG/EARL/EGEARL.xaa.sdf.gz’ saved [8159/8159]
#
# mkdir: created directory 'EG/EARM'
# --2023-02-11 23:12:42--  http://files.docking.org/3D/EG/EARM/EGEARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 245865 (240K) [application/x-gzip]
# Saving to: ‘EG/EARM/EGEARM.xaa.sdf.gz’
#
# EG/EARM/EGEARM.xaa. 100%[===================>] 240.10K   754KB/s    in 0.3s
#
# 2023-02-11 23:12:42 (754 KB/s) - ‘EG/EARM/EGEARM.xaa.sdf.gz’ saved [245865/245865]
#
# mkdir: created directory 'EG/EARO'
# --2023-02-11 23:12:42--  http://files.docking.org/3D/EG/EARO/EGEARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 529909 (517K) [application/x-gzip]
# Saving to: ‘EG/EARO/EGEARO.xaa.sdf.gz’
#
# EG/EARO/EGEARO.xaa. 100%[===================>] 517.49K  1.30MB/s    in 0.4s
#
# 2023-02-11 23:12:43 (1.30 MB/s) - ‘EG/EARO/EGEARO.xaa.sdf.gz’ saved [529909/529909]
#
# mkdir: created directory 'EG/EARP'
# --2023-02-11 23:12:43--  http://files.docking.org/3D/EG/EARP/EGEARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12567 (12K) [application/x-gzip]
# Saving to: ‘EG/EARP/EGEARP.xaa.sdf.gz’
#
# EG/EARP/EGEARP.xaa. 100%[===================>]  12.27K  --.-KB/s    in 0s
#
# 2023-02-11 23:12:43 (142 MB/s) - ‘EG/EARP/EGEARP.xaa.sdf.gz’ saved [12567/12567]
#
# mkdir: created directory 'EG/EBML'
# --2023-02-11 23:12:43--  http://files.docking.org/3D/EG/EBML/EGEBML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 691 [application/x-gzip]
# Saving to: ‘EG/EBML/EGEBML.xaa.sdf.gz’
#
# EG/EBML/EGEBML.xaa. 100%[===================>]     691  --.-KB/s    in 0s
#
# 2023-02-11 23:12:43 (39.5 MB/s) - ‘EG/EBML/EGEBML.xaa.sdf.gz’ saved [691/691]
#
# mkdir: created directory 'EG/EBMM'
# --2023-02-11 23:12:43--  http://files.docking.org/3D/EG/EBMM/EGEBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68530 (67K) [application/x-gzip]
# Saving to: ‘EG/EBMM/EGEBMM.xaa.sdf.gz’
#
# EG/EBMM/EGEBMM.xaa. 100%[===================>]  66.92K   408KB/s    in 0.2s
#
# 2023-02-11 23:12:44 (408 KB/s) - ‘EG/EBMM/EGEBMM.xaa.sdf.gz’ saved [68530/68530]
#
# mkdir: created directory 'EG/EBMO'
# --2023-02-11 23:12:44--  http://files.docking.org/3D/EG/EBMO/EGEBMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 218741 (214K) [application/x-gzip]
# Saving to: ‘EG/EBMO/EGEBMO.xaa.sdf.gz’
#
# EG/EBMO/EGEBMO.xaa. 100%[===================>] 213.61K   597KB/s    in 0.4s
#
# 2023-02-11 23:12:44 (597 KB/s) - ‘EG/EBMO/EGEBMO.xaa.sdf.gz’ saved [218741/218741]
#
# mkdir: created directory 'EG/EBMP'
# --2023-02-11 23:12:44--  http://files.docking.org/3D/EG/EBMP/EGEBMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6413 (6.3K) [application/x-gzip]
# Saving to: ‘EG/EBMP/EGEBMP.xaa.sdf.gz’
#
# EG/EBMP/EGEBMP.xaa. 100%[===================>]   6.26K  --.-KB/s    in 0s
#
# 2023-02-11 23:12:44 (450 MB/s) - ‘EG/EBMP/EGEBMP.xaa.sdf.gz’ saved [6413/6413]
#
# mkdir: created directory 'EG/EBRL'
# --2023-02-11 23:12:44--  http://files.docking.org/3D/EG/EBRL/EGEBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12408 (12K) [application/x-gzip]
# Saving to: ‘EG/EBRL/EGEBRL.xaa.sdf.gz’
#
# EG/EBRL/EGEBRL.xaa. 100%[===================>]  12.12K  --.-KB/s    in 0s
#
# 2023-02-11 23:12:45 (122 MB/s) - ‘EG/EBRL/EGEBRL.xaa.sdf.gz’ saved [12408/12408]
#
# mkdir: created directory 'EG/EBRM'
# --2023-02-11 23:12:45--  http://files.docking.org/3D/EG/EBRM/EGEBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 338855 (331K) [application/x-gzip]
# Saving to: ‘EG/EBRM/EGEBRM.xaa.sdf.gz’
#
# EG/EBRM/EGEBRM.xaa. 100%[===================>] 330.91K   830KB/s    in 0.4s
#
# 2023-02-11 23:12:45 (830 KB/s) - ‘EG/EBRM/EGEBRM.xaa.sdf.gz’ saved [338855/338855]
#
# mkdir: created directory 'EG/EBRO'
# --2023-02-11 23:12:45--  http://files.docking.org/3D/EG/EBRO/EGEBRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 327684 (320K) [application/x-gzip]
# Saving to: ‘EG/EBRO/EGEBRO.xaa.sdf.gz’
#
# EG/EBRO/EGEBRO.xaa. 100%[===================>] 320.00K   969KB/s    in 0.3s
#
# 2023-02-11 23:12:46 (969 KB/s) - ‘EG/EBRO/EGEBRO.xaa.sdf.gz’ saved [327684/327684]
#
# mkdir: created directory 'EG/EBRP'
# --2023-02-11 23:12:46--  http://files.docking.org/3D/EG/EBRP/EGEBRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6649 (6.5K) [application/x-gzip]
# Saving to: ‘EG/EBRP/EGEBRP.xaa.sdf.gz’
#
# EG/EBRP/EGEBRP.xaa. 100%[===================>]   6.49K  --.-KB/s    in 0s
#
# 2023-02-11 23:12:46 (418 MB/s) - ‘EG/EBRP/EGEBRP.xaa.sdf.gz’ saved [6649/6649]

# %% [markdown]
# # Processing after download

# %%
#@title Write a bash for processing
com_file = open('1.sh','w')
com_file.write('''
#!/bin/bash

# 进入每个子文件夹
for dir in */; do
  cd "$dir"
  # 进入内部文件夹
  for inner_dir in */; do
    cd "$inner_dir"
    # 解压所有.gz文件
    for file in *.gz; do
      gunzip "$file"
    done
    # 复制所有解压后的文件到上层文件夹
    mv *.sdf ../../
    cd ../
  done
  cd ../
done

# 合并所有文件
cat *.sdf > all_zinc.sdf   
''')
com_file.close()

# %%
#@title Run bash
# !sh 1.sh
# Out:
# gzip: DCAAMO.xab.sdf.gz: unexpected end of file
#
# gzip: DCAARO.xab.sdf.gz: unexpected end of file
#
# gzip: EFBAMP.xaa.sdf.gz: unexpected end of file
#
# gzip: EGBAMP.xaa.sdf.gz: unexpected end of file
#
# gzip: EGEAML.xaa.sdf.gz: unexpected end of file
# 1.sh: 9: cd: can't cd to */
# gzip: *.gz: No such file or directory
# 1.sh: 6: cd: can't cd to sample_data/
# gzip: *.gz: No such file or directory
# cp: -r not specified; omitting directory './X11'
# gzip: *.gz: No such file or directory
# cp: cannot stat './*': No such file or directory
#
# gzip: DCAAMO.xab.sdf.gz: unexpected end of file
#
# gzip: DCAARO.xab.sdf.gz: unexpected end of file
#
# gzip: EFBAMP.xaa.sdf.gz: unexpected end of file
#
# gzip: EGBAMP.xaa.sdf.gz: unexpected end of file
#
# gzip: EGEAML.xaa.sdf.gz: unexpected end of file
# cp: -r not specified; omitting directory './CA'
# cp: -r not specified; omitting directory './CB'
# cp: -r not specified; omitting directory './CC'
# cp: -r not specified; omitting directory './CD'
# cp: -r not specified; omitting directory './CE'
# cp: -r not specified; omitting directory './CF'
# cp: -r not specified; omitting directory './CG'
# cp: -r not specified; omitting directory './DA'
# cp: -r not specified; omitting directory './DB'
# cp: -r not specified; omitting directory './DC'
# cp: -r not specified; omitting directory './DD'
# cp: -r not specified; omitting directory './DE'
# cp: -r not specified; omitting directory './DF'
# cp: -r not specified; omitting directory './DG'
# cp: -r not specified; omitting directory './EA'
# cp: -r not specified; omitting directory './EB'
# cp: -r not specified; omitting directory './EC'
# cp: -r not specified; omitting directory './ED'
# cp: -r not specified; omitting directory './EE'
# cp: -r not specified; omitting directory './EF'
# cp: -r not specified; omitting directory './EG'
# cp: -r not specified; omitting directory './Zinc-Million'
# cp: -r not specified; omitting directory './sample_data'
# gzip: *.gz: No such file or directory
# cp: -r not specified; omitting directory './web'
# gzip: *.gz: No such file or directory
# cp: -r not specified; omitting directory './fd'
# cp: error writing '../../full': No space left on device
# cp: error reading './fuse': Operation not permitted
# cp: -r not specified; omitting directory './mqueue'
