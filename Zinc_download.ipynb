# %% [markdown]
# <a href="https://colab.research.google.com/github/quantaosun/Zinc-Million/blob/main/Zinc_download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prepare for downloading
# - This should be updated overtime
# - The default one is generated on 10 Feb 2023

# %%
# !git clone https://github.com/quantaosun/Zinc-Million.git
# !cp /content/Zinc-Million/ZINC-downloader-3D-sdf.gz.wget .
# !cat ZINC-downloader-3D-sdf.gz.wget > download.sh
# Out:
# Cloning into 'Zinc-Million'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 31 (delta 11), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (31/31), 45.93 KiB | 452.00 KiB/s, done.

# %% [markdown]
# # Download

# %%
# !sh download.sh
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8958 (8.7K) [application/x-gzip]
# Saving to: ‘DD/EBRL/DDEBRL.xaa.sdf.gz’
#
# DD/EBRL/DDEBRL.xaa. 100%[===================>]   8.75K  --.-KB/s    in 0s
#
# 2023-02-11 23:07:35 (141 MB/s) - ‘DD/EBRL/DDEBRL.xaa.sdf.gz’ saved [8958/8958]
#
# mkdir: created directory 'DD/EBRM'
# --2023-02-11 23:07:35--  http://files.docking.org/3D/DD/EBRM/DDEBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.3
# Connecting to files.docking.org (files.docking.org)|169.230.75.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 136532 (133K) [application/x-gzip]
# Saving to: ‘DD/EBRM/DDEBRM.xaa.sdf.gz’
#
# DD/EBRM/DDEBRM.xaa. 100%[===================>] 133.33K   394KB/s    in 0.3s
#
# ...

# %% [markdown]
# # Processing after download

# %%
#@title Write a bash for processing
com_file = open('1.sh','w')
com_file.write('''
#!/bin/bash

# 进入每个子文件夹
for dir in */; do
  cd "$dir"
  # 进入内部文件夹
  for inner_dir in */; do
    cd "$inner_dir"
    # 解压所有.gz文件
    for file in *.gz; do
      gunzip "$file"
    done
    # 复制所有解压后的文件到上层文件夹
    cp ./* ../../
    cd ../
  done
  cd ../
done

# 合并所有文件
cat *.sdf > all_zinc.sdf   
''')
com_file.close()

# %%
#@title Run bash
# !sh 1.sh

# %% [markdown]
# - The final result stored in the 000 folder
# - Please download it by right click
